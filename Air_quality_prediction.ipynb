# %% [markdown]
# # Air Quality Priction

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline 
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Out:
# C:\Users\vivek\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Importing the Data

# %%
air_quality = pd.read_excel('AirQualityUCI.xlsx')

# %%
air_quality
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %% [markdown]
# ## Data Frame

# %%
df = pd.read_excel('AirQualityUCI.xlsx')

# %%
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %%
df.shape
# Out:
# (9357, 15)

# %%
air_quality.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...

# %%
air_quality.tail()
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352        1101.25    471.7        538.50    189.8       1374.25
# 9353        1027.00    353.3        603.75    179.2       1263.50
# 9354        1062.50    293.0        603.25    174.7       1240.75
# 9355         960.50    234.5        701.50    155.7       1041.00
# 9356        1047.25    265.2        654.00    167.7       1128.50
#
#       PT08.S5(O3)       T      RH        AH
# 9352      1728.50  21.850  29.250  0.756824
# 9353      1269.00  24.325  23.725  0.711864
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9357, step=1)

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
plt.figure(figsize=(8,3),dpi=100)
sns.heatmap(df.isnull(),cbar=False,cmap='viridis',yticklabels=False);

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Standardizing with Scikit-Learn

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()

# %%
features_plot = ['C6H6(GT)', 'RH', 'AH', 'PT08.S1(CO)']

data_to_plot = air_quality[features_plot]
data_to_plot = scalar.fit_transform(data_to_plot)
data_to_plot = pd.DataFrame(data_to_plot)

sns.pairplot(data_to_plot, size=2.0);
plt.tight_layout()
plt.show()
# Out:
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.heatmap(air_quality.corr(),annot=True)

fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
sns.pairplot(air_quality[["Date","Time","CO(GT)","PT08.S1(CO)","NMHC(GT)","C6H6(GT)","PT08.S2(NMHC)","NOx(GT)","PT08.S3(NOx)","NO2(GT)","PT08.S4(NO2)","PT08.S5(O3)"]],diag_kind = "auto")

# %%
x = air_quality

# %%
x = x.drop('Date', axis=1)
x = x.drop('Time', axis=1)
x = x.drop('C6H6(GT)', axis=1)
x = x.drop('PT08.S4(NO2)', axis=1)

# %%
y = air_quality['C6H6(GT)'].values

x = x.values

# %% [markdown]
# # Train and Test Split Dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((6549, 11), (6549,), (2808, 11), (2808,))

# %% [markdown]
# ## 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([   7.11682599,   13.62204151,    6.80527887, ..., -199.97738344,
#          10.75645428,    5.15238241])

# %%
lr.score(X_train, y_train)
# Out:
# 0.9992904669674652

# %%
print("Train R^2 score  :  ", lr.score(X_train, y_train))
# Out:
# Train R^2 score  :   0.9992904669674652

# %%
lr.score(X_test, y_test)
# Out:
# 0.9990801320164672

# %%
print("Test R^2 score =  ", lr.score(X_test, y_test))
# Out:
# Test R^2 score =   0.9990801320164672

# %%
print("Train data Accuracy = {}".format(lr.score(X_train, y_train)))
# Out:
# Train data Accuracy = 0.9992904669674652

# %%
print("Test data Accuracy: {}".format(lr.score(X_test, y_test)))
# Out:
# Test data Accuracy: 0.9990801320164672

# %% [markdown]
# ## 2. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dtr.predict(X_test)
y_pred
# Out:
# array([   7.28742295,   13.50683251,    6.84989194, ..., -200.        ,
#           9.64557223,    5.51380106])

# %%
dtr.score(X_train, y_train)
# Out:
# 1.0

# %%
print("Train R^2 score  :  ", dtr.score(X_train, y_train))
# Out:
# Train R^2 score  :   1.0

# %%
print("Train data Accuracy: {}".format(dtr.score(X_train, y_train)))
# Out:
# Train data Accuracy: 1.0

# %%
print("Test R^2 score  :  ", dtr.score(X_test, y_test))
# Out:
# Test R^2 score  :   0.9999979017089432

# %%
print("Test data Accuracy: {}".format(dtr.score(X_test, y_test)))
# Out:
# Test data Accuracy: 0.9999979017089432

# %% [markdown]
# ## 3. Lasso regression

# %%
from sklearn.linear_model import Lasso

las = Lasso(alpha=1.0)

# %%
las.fit(X_train, y_train)
# Out:
# Lasso()

# %%
las.score(X_train, y_train)
# Out:
# 0.9992063077553144

# %%
print("Train R^2 score  :  ", las.score(X_train, y_train))
# Out:
# Test R^2 score  :   0.9992063077553144

# %%
print("Train data Accuracy: {}".format(las.score(X_train, y_train)))
# Out:
# Train data Accuracy: 0.9992063077553144

# %%
las.score(X_test, y_test)
# Out:
# 0.9989882334738504

# %%
print("Test R^2 score  :  ", las.score(X_test, y_test))
# Out:
# Test R^2 score  :   0.9989882334738504

# %%
print("Test data Accuracy: {}".format(las.score(X_test, y_test)))
# Out:
# Test data Accuracy: 0.9989882334738504

# %% [markdown]
# ## Model Training

# %%
from sklearn.metrics import r2_score

# %%
import numpy as np
def evaluate_model(true, predicted):
    r2_square = r2_score(true, predicted)
    return r2_square

# %% [markdown]
# ## Train multiple models

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'DecisionTreeRegressor':DecisionTreeRegressor()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test) 
    r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# R2 score 99.90801320164671
# ...
#
#
# Lasso
# Model Training Performance
# R2 score 99.89882334738503
# ...
#
#
# DecisionTreeRegressor
# Model Training Performance
# R2 score 99.99953752119556
# ...
